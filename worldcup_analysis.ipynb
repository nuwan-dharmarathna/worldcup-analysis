# %% [markdown]
# ## Importing the Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

import os

# %% [markdown]
# ## Importing the Libraries

# %%
folder_path = './data/WorldCup_Stats'

# Get the all csv files into a list
csv_files = [file for file in os.listdir(folder_path) if file.endswith('.csv')]

# %%
# Combine all DataFrames into crick_df
crick_df = pd.concat([pd.read_csv(os.path.join(folder_path, file)) for file in csv_files], ignore_index=True)

# %%
# crick_df.to_csv('./data/crick_df.csv')

# %% [markdown]
# ## Exploration and Cleaning the crick_df

# %%
# Check is there any duplicate values

print(crick_df.duplicated().sum())
# Out:
# 0

# %%
crick_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 528 entries, 0 to 527
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0.1     528 non-null    int64
#  1   Unnamed: 0       528 non-null    int64
#  2   date             364 non-null    object
#  3   venue            528 non-null    object
#  4   match_category   528 non-null    object
#  5   team_1           528 non-null    object
#  6   team_2           528 non-null    object
#  7   team_1_runs      518 non-null    float64
#  8   team_1_wickets   518 non-null    float64
#  9   team_2_runs      513 non-null    float64
#  10  team_2_wickets   513 non-null    float64
#  11  result           528 non-null    object
#  12  pom              510 non-null    object
#  13  best_batters     250 non-null    object
#  14  best_bowlers     250 non-null    object
#  15  commentary_line  83 non-null     object
#  16  world_cup_year   528 non-null    int64
#  17  host_country     528 non-null    object
# dtypes: float64(4), int64(3), object(11)
# memory usage: 74.4+ KB

# %% [markdown]
# ## Handling Missing Values

# %% [markdown]
# Let's consider the `team_1_runs` column.

# %%
null_recs = crick_df[crick_df['team_1_runs'].isnull()]
null_recs.head()
# Out:
#     Unnamed: 0.1  Unnamed: 0        date           venue match_category  \
# 11            11           7         NaN        The Oval   League-Match
# 24             7          13  1996-02-25   Colombo (RPS)   League-Match
# 37            20           4         NaN   Colombo (RPS)   League-Match
# 66             9          10  2019-06-07         Bristol   League-Match
# 68            11          17  2019-06-13      Nottingham   League-Match
#
#       team_1       team_2  team_1_runs  team_1_wickets  team_2_runs  \
# 11        SL           WI          NaN             NaN          NaN
# 24        SL           WI          NaN             NaN          NaN
# 37        SL          AUS          NaN             NaN          NaN
# 66  Pakistan    Sri Lanka          NaN             NaN          NaN
# 68     India  New Zealand          NaN             NaN          NaN
#
#     team_2_wickets                                          result  pom  \
# 11             NaN           Match abandoned without a ball bowled  NaN
# 24             NaN  Sri Lanka won (walkover without a ball bowled)  NaN
# 37             NaN  Sri Lanka won (walkover without a ball bowled)  NaN
# 66             NaN           Match abandoned without a ball bowled  NaN
# 68             NaN           Match abandoned without a ball bowled  NaN
#
#    best_batters best_bowlers commentary_line  world_cup_year host_country
# 11          NaN          NaN             NaN            1979      England
# 24          NaN          NaN             NaN            1996    Sri Lanka
# 37          NaN          NaN             NaN            1996    Sri Lanka
# 66          NaN          NaN             NaN            2019      England
# 68          NaN          NaN             NaN            2019      England

# %% [markdown]
# Considering null records in `crick_df['team_1_runs']`,
#
#
# *   All of the records in the columns `team_1_runs`, `team_2_runs`, `team_1_wickets`, and `team_2_wickets` are missing values.
#
# *   However, the result column indicates that some of these matches were marked as **"Match abandoned."**
#
# Therefore, we cannot remove these records immediately, as we plan to add a new column in the future to indicate the final match status (e.g., whether the match was played or abandoned).

# %%
# Let's add 0 values for the values given as match abandoned in result column

# Identify abandoned rows
abandoned_matches = crick_df['result'].str.contains('Match abandoned without a ball bowled', case=False, na=False)

# Update team_1_runs, team_2_runs, team_1_wickets, team_2_wickets to 0 for abandoned matches
crick_df.loc[abandoned_matches, ['team_1_runs', 'team_2_runs', 'team_1_wickets', 'team_2_wickets']] = 0

# %%
#Verify Chancges
crick_df[crick_df['result'].str.contains('Match abandoned without a ball bowled', case=False, na=False)].head()
# Out:
#      Unnamed: 0.1  Unnamed: 0        date        venue match_category  \
# 11             11           7         NaN     The Oval   League-Match
# 66              9          10  2019-06-07      Bristol   League-Match
# 68             11          17  2019-06-13   Nottingham   League-Match
# 93             36          15  2019-06-11      Bristol   League-Match
# 440            48          10         NaN     Brisbane   League-Match
#
#          team_1       team_2  team_1_runs  team_1_wickets  team_2_runs  \
# 11           SL           WI          0.0             0.0          0.0
# 66     Pakistan    Sri Lanka          0.0             0.0          0.0
# 68        India  New Zealand          0.0             0.0          0.0
# 93   Bangladesh    Sri Lanka          0.0             0.0          0.0
# 440   Australia   Bangladesh          0.0             0.0          0.0
#
#      team_2_wickets                                 result  pom best_batters  \
# 11              0.0  Match abandoned without a ball bowled  NaN          NaN
# 66              0.0  Match abandoned without a ball bowled  NaN          NaN
# 68              0.0  Match abandoned without a ball bowled  NaN          NaN
# 93              0.0  Match abandoned without a ball bowled  NaN          NaN
# 440             0.0  Match abandoned without a ball bowled  NaN          NaN
#
#     best_bowlers commentary_line  world_cup_year host_country
# 11           NaN             NaN            1979      England
# 66           NaN             NaN            2019      England
# 68           NaN             NaN            2019      England
# 93           NaN             NaN            2019      England
# 440          NaN             NaN            2015    Australia

# %% [markdown]
# Let's consider the `team_2_runs` column.

# %%
null_recs = crick_df[crick_df['team_2_runs'].isnull()]
null_recs.head()
# Out:
#      Unnamed: 0.1  Unnamed: 0        date           venue match_category  \
# 24              7          13  1996-02-25   Colombo (RPS)   League-Match
# 28             11          15  1996-02-26           Patna   League-Match
# 37             20           4         NaN   Colombo (RPS)   League-Match
# 103            46          14  2019-06-10     Southampton   League-Match
# 323            40          19  2011-03-05   Colombo (RPS)   League-Match
#
#     team_1 team_2  team_1_runs  team_1_wickets  team_2_runs  team_2_wickets  \
# 24      SL     WI          NaN             NaN          NaN             NaN
# 28     ZIM  KENYA         45.0             3.0          NaN             NaN
# 37      SL    AUS          NaN             NaN          NaN             NaN
# 103     SA     WI         29.0             2.0          NaN             NaN
# 323     SL    AUS        146.0             3.0          NaN             NaN
#
#                                              result  pom  \
# 24   Sri Lanka won (walkover without a ball bowled)  NaN
# 28                                        No result  NaN
# 37   Sri Lanka won (walkover without a ball bowled)  NaN
# 103                                       No result  NaN
# 323                                       No result  NaN
#
#                                           best_batters  \
# 24                                                 NaN
# 28                                                 NaN
# 37                                                 NaN
# 103      ['Q de Kock - 17 runs ', 'HM Amla - 6 runs ']
# 323  ['KC Sangakkara - 73 runs ', 'TT Samaraweera -...
#
#                             best_bowlers  \
# 24                                   NaN
# 28                                   NaN
# 37                                   NaN
# 103  ['SS Cottrell - 2', 'O Thomas - 0']
# 323         ['SW Tait - 1', 'B Lee - 1']
#
#                                        commentary_line  world_cup_year  \
# 24                                                 NaN            1996
# 28                                                 NaN            1996
# 37                                                 NaN            1996
# 103                                                NaN            2019
# 323  19.30 There's no good news, I'm afraid. The ra...            2011
#
#     host_country
# 24     Sri Lanka
# 28         India
# 37     Sri Lanka
# 103      England
# 323    Sri Lanka

# %% [markdown]
# Considering null records in `crick_df['team_2_runs']` and Ignoring the abandoned records,
#
# *   Some of the records in the columns `team_1_runs`, `team_2_runs`, `team_1_wickets`, and `team_2_wickets` are missing.
#
# *   Some `team_1_runs`, `team_1_wickets` contains values. But in the result column mention as the **No Result**
#
# Therefore, we cannot get any clear idea through this records.We can remove them

# %%
# Filter rows

null_team_2_runs = crick_df[
    crick_df['team_2_runs'].isnull() & ~crick_df['result'].str.contains('abandoned', case=False, na=False)
]

null_team_2_runs.head()
# Out:
#      Unnamed: 0.1  Unnamed: 0        date           venue match_category  \
# 24              7          13  1996-02-25   Colombo (RPS)   League-Match
# 28             11          15  1996-02-26           Patna   League-Match
# 37             20           4         NaN   Colombo (RPS)   League-Match
# 103            46          14  2019-06-10     Southampton   League-Match
# 323            40          19  2011-03-05   Colombo (RPS)   League-Match
#
#     team_1 team_2  team_1_runs  team_1_wickets  team_2_runs  team_2_wickets  \
# 24      SL     WI          NaN             NaN          NaN             NaN
# 28     ZIM  KENYA         45.0             3.0          NaN             NaN
# 37      SL    AUS          NaN             NaN          NaN             NaN
# 103     SA     WI         29.0             2.0          NaN             NaN
# 323     SL    AUS        146.0             3.0          NaN             NaN
#
#                                              result  pom  \
# 24   Sri Lanka won (walkover without a ball bowled)  NaN
# 28                                        No result  NaN
# 37   Sri Lanka won (walkover without a ball bowled)  NaN
# 103                                       No result  NaN
# 323                                       No result  NaN
#
#                                           best_batters  \
# 24                                                 NaN
# 28                                                 NaN
# 37                                                 NaN
# 103      ['Q de Kock - 17 runs ', 'HM Amla - 6 runs ']
# 323  ['KC Sangakkara - 73 runs ', 'TT Samaraweera -...
#
#                             best_bowlers  \
# 24                                   NaN
# 28                                   NaN
# 37                                   NaN
# 103  ['SS Cottrell - 2', 'O Thomas - 0']
# 323         ['SW Tait - 1', 'B Lee - 1']
#
#                                        commentary_line  world_cup_year  \
# 24                                                 NaN            1996
# 28                                                 NaN            1996
# 37                                                 NaN            1996
# 103                                                NaN            2019
# 323  19.30 There's no good news, I'm afraid. The ra...            2011
#
#     host_country
# 24     Sri Lanka
# 28         India
# 37     Sri Lanka
# 103      England
# 323    Sri Lanka

# %%
records_to_remove = null_team_2_runs.index

# Remove the records
crick_df = crick_df.drop(records_to_remove)

# %%
crick_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 518 entries, 0 to 527
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0.1     518 non-null    int64
#  1   Unnamed: 0       518 non-null    int64
#  2   date             355 non-null    object
#  3   venue            518 non-null    object
#  4   match_category   518 non-null    object
#  5   team_1           518 non-null    object
#  6   team_2           518 non-null    object
#  7   team_1_runs      518 non-null    float64
#  8   team_1_wickets   518 non-null    float64
#  9   team_2_runs      518 non-null    float64
#  10  team_2_wickets   518 non-null    float64
#  11  result           518 non-null    object
#  12  pom              510 non-null    object
#  13  best_batters     248 non-null    object
#  14  best_bowlers     248 non-null    object
#  15  commentary_line  82 non-null     object
#  16  world_cup_year   518 non-null    int64
#  17  host_country     518 non-null    object
# dtypes: float64(4), int64(3), object(11)
# memory usage: 76.9+ KB

# %% [markdown]
# ## Adding New Columns

# %% [markdown]
# match_status

# %%
crick_df['match_status'] = crick_df['result'].apply(
    lambda x: 'abandoned' if 'match abandoned without a ball bowled' in x.lower() else 'played'
)

# %% [markdown]
# winning_team

# %%
def get_winning_team(result):
    # Check if the word "won" exists in the result
    if isinstance(result, str) and 'won' in result.lower():
      
        return result.lower().split('won')[0].strip()
    # Return an empty string if "won" is not present
    return ''  

crick_df['winning_team'] = crick_df['result'].apply(get_winning_team)

# %% [markdown]
# best_batters and best_bowlers Columns

# %%
def extract_best_batters(best_batter_col):
    # Initialize default values in case there are fewer batters
    batter_1_name, batter_1_runs, batter_2_name, batter_2_runs = 'Unknown', 0, 'Unknown', 0
    
    # Check if the column has values (i.e., it's not an empty list)
    if isinstance(best_batter_col, str) and ',' in best_batter_col:
        # Remove unnecessary spaces and split by the comma
        batters = [batter.strip() for batter in best_batter_col.strip("[]").split(',')]
        
       
        if (batters):
           # Extract information for batter 1
            batter_1_name, batter_1_runs = batters[0].split(' - ')

            batter_1_name = batter_1_name.replace("'", "").replace('"', "")
            batter_1_runs = batter_1_runs.replace("runs '", "").replace('runs "', "").strip()
        
            # Extract information for batter 2
            batter_2_name, batter_2_runs = batters[1].split(' - ')

            batter_2_name = batter_2_name.replace("'", "").replace('"', "")
            batter_2_runs = batter_2_runs.replace("runs '", "").replace('runs "', "").strip()

    return batter_1_name, batter_1_runs, batter_2_name, batter_2_runs

# Apply the function to extract the information into new columns
crick_df[['best_batter_1', 'best_batter_1_runs', 'best_batter_2', 'best_batter_2_runs']] = crick_df['best_batters'].apply(
    lambda x: pd.Series(extract_best_batters(x))
)

# %%
def extract_best_ballers(best_baller_col):
    # Initialize default values in case there are fewer batters
    baller_1_name, baller_1_wickets, baller_2_name, baller_2_wickets = 'Unknown', 0, 'Unknown', 0
    
    # Check if the column has values (i.e., it's not an empty list)
    if isinstance(best_baller_col, str) and ',' in best_baller_col:
        # Remove unnecessary spaces and split by the comma
        ballers = [baller.strip() for baller in best_baller_col.strip("[]").split(',')]
        
       
        if (ballers):
           # Extract information for baller 1
            baller_1_name, baller_1_wickets = ballers[0].split(' - ')

            baller_1_name = baller_1_name.replace("'", "").replace('"', "")
            baller_1_wickets = int(baller_1_wickets.replace("'", "").replace('"', ""))
        
            # Extract information for baller 2
            baller_2_name, baller_2_wickets = ballers[1].split(' - ')

            baller_2_name = baller_2_name.replace("'", "").replace('"', "")
            baller_2_wickets = int(baller_2_wickets.replace("'", "").replace('"', ""))

    return baller_1_name, baller_1_wickets, baller_2_name, baller_2_wickets

# Apply the function to extract the information into new columns
crick_df[['best_baller_1', 'best_baller_1_wick', 'best_baller_2', 'best_baller_2_wick']] = crick_df['best_bowlers'].apply(
    lambda x: pd.Series(extract_best_ballers(x))
)

# %%
# Remove unwanted columns from this dataset

crick_df = crick_df.drop(columns=['Unnamed: 0', 'Unnamed: 0.1', 'date', 'commentary_line', 'best_batters', 'best_bowlers', 'result'])

# %% [markdown]
# ## Compute correlation

# %%
# crick_df['team_1'].value_counts()
# crick_df['team_2'].value_counts()
# crick_df['host_country'].value_counts()
crick_df['winning_team'].value_counts()
# Out:
# winning_team
# australia                                               77
# new zealand                                             63
# india                                                   63
# england                                                 56
# pakistan                                                51
# south africa                                            49
# west indies                                             47
# sri lanka                                               40
# bangladesh                                              16
#                                                         12
# zimbabwe                                                11
# kenya                                                    7
# ireland                                                  7
# afghanistan                                              5
# netherlands                                              4
# match tied (england                                      2
# canada                                                   2
# p1 v p4 - india                                          1
# u.a.e.                                                   1
# p2 v p3 - australia                                      1
# a1 v c1 - australia                                      1
# d2 v b2 - west indies                                    1
# winner qf4 (nz v wi) v winner qf1 (sa) - new zealand     1
# Name: count, dtype: int64

# %% [markdown]
# There are some mismatched country types included in above columns. Convert them into Standard type

# %%
def naming_countries(country):
    country = country.lower()
    if country == 'australia':
        return 'AUS'
    elif country == 'bangladesh':
        return 'BAN'
    elif country == 'pakistan':
        return 'PAK'
    elif country == 'west indies':
        return 'WI'
    elif country == 'new zealand':
        return 'NZ'
    elif country == 'india':
        return 'IND'
    elif country == 'sri lanka':
        return 'SL'  
    elif country == 'england':
        return 'ENG'
    elif country == 'south africa':
        return 'SA'
    elif country == 'zimbabwe':
        return 'ZIM'
    elif country == 'ireland':
        return 'IRE'
    elif country == 'kenya':
        return 'KENYA'
    elif country == 'afghanistan':
        return 'AFG'
    elif country == 'netherlands':
        return 'NED'
    elif country == 'scotland':
        return 'SCO'
    elif country == 'canada':
        return 'CAN'
    elif country == 'u.a.e':
        return 'UAE'
    else:
        return country.upper()

# %%
# Apply the function to the team_1 and team_2 columns

crick_df['team_1'] = crick_df['team_1'].apply(naming_countries)
crick_df['team_2'] = crick_df['team_2'].apply(naming_countries)

# %%
# Apply the function to the host_country column

crick_df['host_country'] = crick_df['host_country'].apply(naming_countries)

# %%
# Removing mismatched text sections from the winning_team column

crick_df['winning_team'] = crick_df['winning_team'].apply(lambda x: x.split('-')[-1].strip())
crick_df['winning_team'] = crick_df['winning_team'].apply(lambda x: x.split('(')[-1].strip())


# Apply the function to the winning_team columns

crick_df['winning_team'] = crick_df['winning_team'].apply(naming_countries)

# %% [markdown]
# ### Final Steps in Dataset Cleaning
#
# 1. Replace NaN values in the following categorical columns with the placeholder 'Unknown':
#     * pom
#
# 2. Null Values in `winning_team`:
#     * Do not remove null records in the winning_team column, as they correspond to rows where `match_status` is 'abandoned'.

# %%
crick_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 518 entries, 0 to 527
# Data columns (total 21 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   venue               518 non-null    object
#  1   match_category      518 non-null    object
#  2   team_1              518 non-null    object
#  3   team_2              518 non-null    object
#  4   team_1_runs         518 non-null    float64
#  5   team_1_wickets      518 non-null    float64
#  6   team_2_runs         518 non-null    float64
#  7   team_2_wickets      518 non-null    float64
#  8   pom                 510 non-null    object
#  9   world_cup_year      518 non-null    int64
#  10  host_country        518 non-null    object
#  11  match_status        518 non-null    object
#  12  winning_team        518 non-null    object
#  13  best_batter_1       518 non-null    object
#  14  best_batter_1_runs  518 non-null    object
#  15  best_batter_2       518 non-null    object
#  16  best_batter_2_runs  518 non-null    object
#  17  best_baller_1       518 non-null    object
#  18  best_baller_1_wick  518 non-null    int64
#  19  best_baller_2       518 non-null    object
#  20  best_baller_2_wick  518 non-null    int64
# dtypes: float64(4), int64(3), object(14)
# memory usage: 89.0+ KB

# %%
missimg_summary = crick_df.isnull().sum()
missimg_summary
# Out:
# venue                 0
# match_category        0
# team_1                0
# team_2                0
# team_1_runs           0
# team_1_wickets        0
# team_2_runs           0
# team_2_wickets        0
# pom                   8
# world_cup_year        0
# host_country          0
# match_status          0
# winning_team          0
# best_batter_1         0
# best_batter_1_runs    0
# best_batter_2         0
# best_batter_2_runs    0
# best_baller_1         0
# best_baller_1_wick    0
# best_baller_2         0
# best_baller_2_wick    0
# dtype: int64

# %%
crick_df['pom'] = crick_df['pom'].fillna('Unknown')

# Replace '' with 'Unknown' in the winning_team column
crick_df['winning_team'] = crick_df['winning_team'].replace('', 'Unknown')

# %% [markdown]
# ### Checking Duplicates & remove them

# %%
crick_df.duplicated().sum()
# Out:
# np.int64(25)

# %%
# Extract duplicate rows to duplicates
duplicates = crick_df[crick_df.duplicated(keep=False)]

# Display the duplicate rows
duplicates
# Out:
#                    venue match_category team_1 team_2  team_1_runs  \
# 0             Manchester   League-Match    CAN    ENG         45.0
# 6               The Oval     Semi-Final     WI    PAK        293.0
# 7             Manchester   League-Match    CAN    ENG         45.0
# 12              The Oval     Semi-Final     WI    PAK        293.0
# 43               Gwalior   League-Match     WI    IND        173.0
# 46    Hyderabad (Deccan)   League-Match    ZIM     WI        151.0
# 49               Gwalior   League-Match     WI    IND        173.0
# 53    Hyderabad (Deccan)   League-Match    ZIM     WI        151.0
# 67                Lord's          Final     NZ    ENG        241.0
# 70            Manchester   League-Match     NZ    IND        239.0
# 83                Lord's          Final     NZ    ENG        241.0
# 94            Manchester   League-Match     NZ    IND        239.0
# 120               Lord's   League-Match     SL    ENG        204.0
# 124                Derby   League-Match    PAK     NZ        269.0
# 133                Derby   League-Match    PAK     NZ        269.0
# 141               Lord's   League-Match     SL    ENG        204.0
# 155           Providence   League-Match     SL     SA        209.0
# 177           Basseterre   League-Match     SA    NED        353.0
# 187           Providence   League-Match     SL     SA        209.0
# 197           Basseterre   League-Match     SA    NED        353.0
# 214         Eden Gardens   League-Match    ENG    PAK        337.0
# 215            Ahmedabad   League-Match    AFG     SA        244.0
# 241         Eden Gardens   League-Match    ENG    PAK        337.0
# 245            Ahmedabad   League-Match    AFG     SA        244.0
# 256             Wankhede     Semi-Final    ENG    IND        254.0
# 257              Karachi   League-Match     WI    PAK        258.0
# 258             Wankhede     Semi-Final    ENG    IND        254.0
# 260              Karachi   League-Match     WI    PAK        258.0
# 294                Delhi   League-Match     WI    NED        330.0
# 303             Wankhede   League-Match     NZ    CAN        358.0
# 308                Delhi   League-Match     WI    NED        330.0
# 330             Wankhede   League-Match     NZ    CAN        358.0
# 334           Nottingham   League-Match    PAK     SL        330.0
# 338             The Oval     Semi-Final     NZ     WI        158.0
# 342           Nottingham   League-Match    PAK     SL        330.0
# 345             The Oval     Semi-Final     NZ     WI        158.0
# 354               Sydney   League-Match    AUS     SA        170.0
# 363               Sydney   League-Match    AUS     SA        170.0
# 364              Dunedin   League-Match    IND     NZ        230.0
# 367              Dunedin   League-Match    IND     NZ        230.0
# 401            Melbourne          Final     NZ    AUS        183.0
# 413           Wellington          Final     NZ     WI        393.0
# 417            Melbourne          Final     NZ    AUS        183.0
# 439           Wellington          Final     NZ     WI        393.0
# 474         Bloemfontein   League-Match    ZIM  KENYA        133.0
# 478         Bloemfontein   League-Match    ZIM  KENYA        133.0
# 503              Bristol   League-Match     SL     NZ        206.0
# 507              Taunton   League-Match    ENG     SL        333.0
# 512              Taunton   League-Match    ENG     SL        333.0
# 524              Bristol   League-Match     SL     NZ        206.0
#
#      team_1_wickets  team_2_runs  team_2_wickets                    pom  \
# 0               0.0         46.0             2.0              Chris Old
# 6               6.0        250.0             0.0       Gordon Greenidge
# 7               0.0         46.0             2.0              Chris Old
# 12              6.0        250.0             0.0       Gordon Greenidge
# 43              0.0        174.0             5.0       Sachin Tendulkar
# 46              9.0        155.0             4.0         Curtly Ambrose
# 49              0.0        174.0             5.0       Sachin Tendulkar
# 53              9.0        155.0             4.0         Curtly Ambrose
# 67              8.0        241.0             0.0             Ben Stokes
# 70              8.0        221.0             0.0             Matt Henry
# 83              8.0        241.0             0.0             Ben Stokes
# 94              8.0        221.0             0.0             Matt Henry
# 120             0.0        207.0             2.0           Alec Stewart
# 124             8.0        207.0             8.0         Inzamam-ul-Haq
# 133             8.0        207.0             8.0         Inzamam-ul-Haq
# 141             0.0        207.0             2.0           Alec Stewart
# 155             0.0        212.0             9.0       Charl Langeveldt
# 177             3.0        132.0             9.0       Herschelle Gibbs
# 187             0.0        212.0             9.0       Charl Langeveldt
# 197             3.0        132.0             9.0       Herschelle Gibbs
# 214             9.0        244.0             0.0           David Willey
# 215             0.0        247.0             5.0  Rassie van der Dussen
# 241             9.0        244.0             0.0           David Willey
# 245             0.0        247.0             5.0  Rassie van der Dussen
# 256             6.0        219.0             0.0           Graham Gooch
# 257             7.0        230.0             9.0      Richie Richardson
# 258             6.0        219.0             0.0           Graham Gooch
# 260             7.0        230.0             9.0      Richie Richardson
# 294             8.0        115.0             0.0            Kemar Roach
# 303             6.0        261.0             9.0       Brendon McCullum
# 308             8.0        115.0             0.0            Kemar Roach
# 330             6.0        261.0             9.0       Brendon McCullum
# 334             6.0        138.0             0.0           Zaheer Abbas
# 338             0.0        159.0             5.0     Alvin Kallicharran
# 342             6.0        138.0             0.0           Zaheer Abbas
# 345             0.0        159.0             5.0     Alvin Kallicharran
# 354             9.0        171.0             1.0         Kepler Wessels
# 363             9.0        171.0             1.0         Kepler Wessels
# 364             6.0        231.0             6.0        Mark Greatbatch
# 367             6.0        231.0             6.0        Mark Greatbatch
# 401             0.0        186.0             3.0         James Faulkner
# 413             6.0        250.0             0.0         Martin Guptill
# 417             0.0        186.0             3.0         James Faulkner
# 439             6.0        250.0             0.0         Martin Guptill
# 474             0.0        135.0             3.0            Martin Suji
# 478             0.0        135.0             3.0            Martin Suji
# 503             0.0        209.0             5.0         Richard Hadlee
# 507             9.0        286.0             0.0            David Gower
# 512             9.0        286.0             0.0            David Gower
# 524             0.0        209.0             5.0         Richard Hadlee
#
#      world_cup_year  ... match_status winning_team       best_batter_1  \
# 0              1979  ...       played          ENG             Unknown
# 6              1979  ...       played           WI             Unknown
# 7              1979  ...       played          ENG             Unknown
# 12             1979  ...       played           WI             Unknown
# 43             1996  ...       played          IND             Unknown
# 46             1996  ...       played           WI             Unknown
# 49             1996  ...       played          IND             Unknown
# 53             1996  ...       played           WI             Unknown
# 67             2019  ...       played          ENG           BA Stokes
# 70             2019  ...       played           NZ           RA Jadeja
# 83             2019  ...       played          ENG           BA Stokes
# 94             2019  ...       played           NZ           RA Jadeja
# 120            1999  ...       played          ENG             Unknown
# 124            1999  ...       played          PAK             Unknown
# 133            1999  ...       played          PAK             Unknown
# 141            1999  ...       played          ENG             Unknown
# 155            2007  ...       played           SA           JH Kallis
# 177            2007  ...       played           SA           JH Kallis
# 187            2007  ...       played           SA           JH Kallis
# 197            2007  ...       played           SA           JH Kallis
# 214            2023  ...       played          ENG           BA Stokes
# 215            2023  ...       played           SA  Azmatullah Omarzai
# 241            2023  ...       played          ENG           BA Stokes
# 245            2023  ...       played           SA  Azmatullah Omarzai
# 256            1987  ...       played          ENG             Unknown
# 257            1987  ...       played           WI             Unknown
# 258            1987  ...       played          ENG             Unknown
# 260            1987  ...       played           WI             Unknown
# 294            2011  ...       played           WI            CH Gayle
# 303            2011  ...       played           NZ         BB McCullum
# 308            2011  ...       played           WI            CH Gayle
# 330            2011  ...       played           NZ         BB McCullum
# 334            1975  ...       played          PAK             Unknown
# 338            1975  ...       played           WI             Unknown
# 342            1975  ...       played          PAK             Unknown
# 345            1975  ...       played           WI             Unknown
# 354            1992  ...       played           SA             Unknown
# 363            1992  ...       played           SA             Unknown
# 364            1992  ...       played           NZ             Unknown
# 367            1992  ...       played           NZ             Unknown
# 401            2015  ...       played          AUS          GD Elliott
# 413            2015  ...       played           NZ          MJ Guptill
# 417            2015  ...       played          AUS          GD Elliott
# 439            2015  ...       played           NZ          MJ Guptill
# 474            2003  ...       played        KENYA             Unknown
# 478            2003  ...       played        KENYA             Unknown
# 503            1983  ...       played           NZ             Unknown
# 507            1983  ...       played          ENG             Unknown
# 512            1983  ...       played          ENG             Unknown
# 524            1983  ...       played           NZ             Unknown
#
#     best_batter_1_runs      best_batter_2 best_batter_2_runs  best_baller_1  \
# 0                    0            Unknown                  0        Unknown
# 6                    0            Unknown                  0        Unknown
# 7                    0            Unknown                  0        Unknown
# 12                   0            Unknown                  0        Unknown
# 43                   0            Unknown                  0        Unknown
# 46                   0            Unknown                  0        Unknown
# 49                   0            Unknown                  0        Unknown
# 53                   0            Unknown                  0        Unknown
# 67                  84         JC Buttler                 59      CR Woakes
# 70                  77        LRPL Taylor                 74       MJ Henry
# 83                  84         JC Buttler                 59      CR Woakes
# 94                  77        LRPL Taylor                 74       MJ Henry
# 120                  0            Unknown                  0        Unknown
# 124                  0            Unknown                  0        Unknown
# 133                  0            Unknown                  0        Unknown
# 141                  0            Unknown                  0        Unknown
# 155                 86           GC Smith                 59  CK Langeveldt
# 177                128         MV Boucher                 75        JM Kemp
# 187                 86           GC Smith                 59  CK Langeveldt
# 197                128         MV Boucher                 75        JM Kemp
# 214                 84            JE Root                 60      DJ Willey
# 215                 97  HE van der Dussen                 76      G Coetzee
# 241                 84            JE Root                 60      DJ Willey
# 245                 97  HE van der Dussen                 76      G Coetzee
# 256                  0            Unknown                  0        Unknown
# 257                  0            Unknown                  0        Unknown
# 258                  0            Unknown                  0        Unknown
# 260                  0            Unknown                  0        Unknown
# 294                 80         KA Pollard                 60      KAJ Roach
# 303                101            A Bagai                 84       JDP Oram
# 308                 80         KA Pollard                 60      KAJ Roach
# 330                101            A Bagai                 84       JDP Oram
# 334                  0            Unknown                  0        Unknown
# 338                  0            Unknown                  0        Unknown
# 342                  0            Unknown                  0        Unknown
# 345                  0            Unknown                  0        Unknown
# 354                  0            Unknown                  0        Unknown
# 363                  0            Unknown                  0        Unknown
# 364                  0            Unknown                  0        Unknown
# 367                  0            Unknown                  0        Unknown
# 401                 83          MJ Clarke                 74     MG Johnson
# 413                237           CH Gayle                 61       TA Boult
# 417                 83          MJ Clarke                 74     MG Johnson
# 439                237           CH Gayle                 61       TA Boult
# 474                  0            Unknown                  0        Unknown
# 478                  0            Unknown                  0        Unknown
# 503                  0            Unknown                  0        Unknown
# 507                  0            Unknown                  0        Unknown
# 512                  0            Unknown                  0        Unknown
# 524                  0            Unknown                  0        Unknown
#
#     best_baller_1_wick  best_baller_2 best_baller_2_wick
# 0                    0        Unknown                  0
# 6                    0        Unknown                  0
# 7                    0        Unknown                  0
# 12                   0        Unknown                  0
# 43                   0        Unknown                  0
# 46                   0        Unknown                  0
# 49                   0        Unknown                  0
# 53                   0        Unknown                  0
# 67                   3    LE Plunkett                  3
# 70                   3        B Kumar                  3
# 83                   3    LE Plunkett                  3
# 94                   3        B Kumar                  3
# 120                  0        Unknown                  0
# 124                  0        Unknown                  0
# 133                  0        Unknown                  0
# 141                  0        Unknown                  0
# 155                  5     SL Malinga                  4
# 177                  2     SM Pollock                  1
# 187                  5     SL Malinga                  4
# 197                  2     SM Pollock                  1
# 214                  3     Haris Rauf                  3
# 215                  4     KA Maharaj                  2
# 241                  3     Haris Rauf                  3
# 245                  4     KA Maharaj                  2
# 256                  0        Unknown                  0
# 257                  0        Unknown                  0
# 258                  0        Unknown                  0
# 260                  0        Unknown                  0
# 294                  6        SJ Benn                  3
# 303                  3     HS Baidwan                  3
# 308                  6        SJ Benn                  3
# 330                  3     HS Baidwan                  3
# 334                  0        Unknown                  0
# 338                  0        Unknown                  0
# 342                  0        Unknown                  0
# 345                  0        Unknown                  0
# 354                  0        Unknown                  0
# 363                  0        Unknown                  0
# 364                  0        Unknown                  0
# 367                  0        Unknown                  0
# 401                  3    JP Faulkner                  3
# 413                  4      JE Taylor                  3
# 417                  3    JP Faulkner                  3
# 439                  4      JE Taylor                  3
# 474                  0        Unknown                  0
# 478                  0        Unknown                  0
# 503                  0        Unknown                  0
# 507                  0        Unknown                  0
# 512                  0        Unknown                  0
# 524                  0        Unknown                  0
#
# [50 rows x 21 columns]

# %%
crick_df.drop_duplicates(inplace=True)

# %%
crick_df.shape
# Out:
# (493, 21)

# %%
# save the cleaned data to a new csv file

# crick_df.to_csv('./data/crick_df_cleaned.csv')
